# %%
import pandas as pd
titanic_test=pd.read_csv("test.csv")
print(titanic_test)
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age Age Group  Siblings or Spouses  Parents and children  \
# ...

# %%
titanic_train=pd.read_csv("train.csv")
print(titanic_train)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# ...

# %%
Gender =pd.read_csv("gender_submission.csv")
print(Gender)
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
titanic_test.head(30)
# Out:
#     PassengerId  Pclass                                               Name  \
# 0           892       3                                   Kelly, Mr. James
# 1           893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2           894       2                          Myles, Mr. Thomas Francis
# 3           895       3                                   Wirz, Mr. Albert
# 4           896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5           897       3                         Svensson, Mr. Johan Cervin
# 6           898       3                               Connolly, Miss. Kate
# 7           899       2                       Caldwell, Mr. Albert Francis
# 8           900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9           901       3                            Davies, Mr. John Samuel
# 10          902       3                                   Ilieff, Mr. Ylio
# ...

# %%
titanic_train.head(30)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %%
Gender.head(30)
# Out:
#     PassengerId  Survived
# 0           892         0
# 1           893         1
# 2           894         0
# 3           895         0
# 4           896         1
# 5           897         0
# 6           898         1
# 7           899         0
# 8           900         1
# 9           901         0
# 10          902         0
# 11          903         0
# 12          904         1
# 13          905         0
# 14          906         1
# 15          907         1
# 16          908         0
# 17          909         0
# 18          910         1
# 19          911         1
# 20          912         0
# 21          913         0
# 22          914         1
# 23          915         0
# 24          916         1
# 25          917         0
# 26          918         1
# 27          919         0
# 28          920         0
# 29          921         0

# %%
titanic_train.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# ...

# %%
titanic_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   PassengerId           418 non-null    int64
#  1   Pclass                418 non-null    int64
#  2   Name                  418 non-null    object
#  3   Sex                   418 non-null    object
#  4   Age                   332 non-null    float64
#  5   Age Group             331 non-null    object
#  6   Siblings or Spouses   418 non-null    int64
#  7   Parents and children  418 non-null    int64
#  8   Ticket                418 non-null    object
#  9   Fare                  417 non-null    float64
#  10  Cabin                 91 non-null     object
#  11  Embarked              418 non-null    object
#  12  Unnamed: 12           1 non-null      object
# dtypes: float64(2), int64(4), object(7)
# memory usage: 42.6+ KB

# %%
Gender.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
# dtypes: int64(2)
# memory usage: 6.7 KB

# %%
titanic_train.shape
# Out:
# (891, 13)

# %%
titanic_test.shape
# Out:
# (418, 13)

# %%
Gender.shape
# Out:
# (418, 2)

# %%
pd.isnull(titanic_test)
# Out:
#      PassengerId  Pclass   Name    Sex    Age  Age Group  Siblings or Spouses  \
# 0          False   False  False  False  False      False                False
# 1          False   False  False  False  False      False                False
# 2          False   False  False  False  False      False                False
# 3          False   False  False  False  False      False                False
# 4          False   False  False  False  False      False                False
# ..           ...     ...    ...    ...    ...        ...                  ...
# 413        False   False  False  False   True       True                False
# 414        False   False  False  False  False      False                False
# 415        False   False  False  False  False      False                False
# 416        False   False  False  False   True       True                False
# 417        False   False  False  False   True       True                False
#
# ...

# %%
pd.isnull(titanic_train)
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  Age Group  \
# 0          False     False   False  False  False  False      False
# 1          False     False   False  False  False  False      False
# 2          False     False   False  False  False  False      False
# 3          False     False   False  False  False  False      False
# 4          False     False   False  False  False  False      False
# ..           ...       ...     ...    ...    ...    ...        ...
# 886        False     False   False  False  False  False      False
# 887        False     False   False  False  False  False      False
# 888        False     False   False  False  False   True       True
# 889        False     False   False  False  False  False      False
# 890        False     False   False  False  False  False      False
#
#      Siblings and Spouses  Parents & children  Ticket   Fare  Cabin  Embarked
# 0                   False               False   False  False   True     False
# ...

# %%
pd.isnull(Gender)
# Out:
#      PassengerId  Survived
# 0          False     False
# 1          False     False
# 2          False     False
# 3          False     False
# 4          False     False
# ..           ...       ...
# 413        False     False
# 414        False     False
# 415        False     False
# 416        False     False
# 417        False     False
#
# [418 rows x 2 columns]

# %%
pd.isnull(titanic_train).sum()
# Out:
# PassengerId               0
# Survived                  0
# Pclass                    0
# Name                      0
# Sex                       0
# Age                     177
# Age Group               179
# Siblings and Spouses      0
# Parents & children        0
# Ticket                    0
# Fare                      0
# Cabin                   687
# Embarked                  2
# dtype: int64

# %%
titanic_train=titanic_train.drop(columns='Cabin',axis=1)

# %%
titanic_train['Age'].fillna(titanic_train['Age'].mean(),inplace=True)

# %%
titanic_train.isnull().sum()
# Out:
# PassengerId               0
# Survived                  0
# Pclass                    0
# Name                      0
# Sex                       0
# Age                       0
# Age Group               179
# Siblings and Spouses      0
# Parents & children        0
# Ticket                    0
# Fare                      0
# Embarked                  2
# dtype: int64

# %%
#alerts fix embarked
print(titanic_train['Embarked'].mode())
# Out:
# 0    S
# Name: Embarked, dtype: object

# %% [markdown]
# The term "Embarked" is used/refers to the port of embarkation for each passenger. "Embarked" can be used as a feature in machine learning models to predict survival or other outcomes. For example, it might capture certain geographical or cultural factors that influence survival probabilities.Overall, the "Embarked" feature can provide valuable information for understanding the demographics, socio-economic factors, and travel patterns of Titanic passengers, making it relevant for analysis and modeling purposes.
# Understanding Passenger Demographics: Analyzing the distribution of passengers across different embarkation ports can provide insights into the demographics of passengers from various regions.
#
# Exploring Socio-Economic Factors: The port of embarkation might be correlated with socio-economic status or nationality, which could influence survival rates or other outcomes.
#
# Analyzing Travel Routes: Studying the embarkation ports can help in understanding the travel routes of the Titanic and potential patterns related to passenger origins and destinations.
#
# Overall, the "Embarked" feature can provide valuable information for understanding the demographics, socio-economic factors, and travel patterns of Titanic passengers, making it relevant for analysis and modeling purposes.

# %%
print(titanic_train["Embarked"].mode()[0])
# Out:
# S

# %%
titanic_train["Embarked"].fillna(titanic_train['Embarked'].mode()[0],inplace=True)

# %%
titanic_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age  Siblings and Spouses  \
# count   891.000000  891.000000  891.000000  891.000000            891.000000
# mean    446.000000    0.383838    2.308642   29.699118              0.523008
# std     257.353842    0.486592    0.836071   13.002015              1.102743
# min       1.000000    0.000000    1.000000    0.420000              0.000000
# 25%     223.500000    0.000000    2.000000   22.000000              0.000000
# 50%     446.000000    0.000000    3.000000   29.699118              0.000000
# 75%     668.500000    1.000000    3.000000   35.000000              1.000000
# max     891.000000    1.000000    3.000000   80.000000              8.000000
#
#        Parents & children        Fare
# count          891.000000  891.000000
# mean             0.381594   32.204208
# std              0.806057   49.693429
# min              0.000000    0.000000
# 25%              0.000000    7.910400
# 50%              0.000000   14.454200
# ...

# %%
titanic_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'Age Group',
#        'Siblings and Spouses', 'Parents & children', 'Ticket', 'Fare',
#        'Embarked'],
#       dtype='object')

# %%
titanic_train[["Name","Age","Survived"]].describe()
# Out:
#               Age    Survived
# count  891.000000  891.000000
# mean    29.699118    0.383838
# std     13.002015    0.486592
# min      0.420000    0.000000
# 25%     22.000000    0.000000
# 50%     29.699118    0.000000
# 75%     35.000000    1.000000
# max     80.000000    1.000000

# %% [markdown]
# Data Analysis

# %%
#to show how many people survived
titanic_train['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
import seaborn as sns
sns.countplot(x='Survived',data=titanic_train)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='Sex',data=titanic_train)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
#We use bar chart to count the values of gender.
ax=sns.countplot(x='Sex',data=titanic_train)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sns.countplot(x='Sex',hue='Survived',data=titanic_train)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x='Pclass',data=titanic_train)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
ay=sns.countplot(x='Pclass',data=titanic_train)
for bars in ay.containers:
    ay.bar_label(bars)

# %%
sns.countplot(x='Pclass',hue='Survived',data=titanic_train)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
ax=sns.countplot(x='Pclass',hue='Survived',data=titanic_train)
for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# PClass = PassengerClass The gender wise survival in (0's non surival,1's survival) and is found that Class3 more number of deaths,least deaths in class 1 and moderate deaths in class 2. Overall,according to priority the men have more deaths than female and kids.

# %% [markdown]
# Encoding Categorical columns/data.

# %%
titanic_train['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
titanic_train['Embarked'].value_counts()
# Out:
# Embarked
# S    646
# C    168
# Q     77
# Name: count, dtype: int64

# %%
titanic_train.replace({'Sex':{'male':0,'female':1},'Embarked':{'S':0,'C':1,'Q':2}})
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex        Age  \
# 0                              Braund, Mr. Owen Harris    0  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.000000
# 2                               Heikkinen, Miss. Laina    1  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.000000
# 4                             Allen, Mr. William Henry    0  35.000000
# ..                                                 ...  ...        ...
# ...

# %%
#predict the survival rate and hence the survival is the target columns.
X=titanic_train.drop(columns=['PassengerId','Name','Survived','Ticket'],axis=1)#here I wanted to drop columns which I don't need as far as concerned (axis=1) performs reversed i.e. it drops the columns which is not mentioned in the [columns]
Y=titanic_train['Survived']
print(X)
# Out:
#      Pclass     Sex        Age Age Group  Siblings and Spouses  \
# 0         3    male  22.000000     Adult                     1
# 1         1  female  38.000000     Adult                     1
# 2         3  female  26.000000     Adult                     0
# 3         1  female  35.000000     Adult                     1
# 4         3    male  35.000000     Adult                     0
# ..      ...     ...        ...       ...                   ...
# 886       2    male  27.000000     Adult                     0
# 887       1  female  19.000000     Adult                     0
# 888       3  female  29.699118       NaN                     1
# 889       1    male  26.000000     Adult                     0
# 890       3    male  32.000000     Adult                     0
#
#      Parents & children     Fare Embarked
# 0                     0   7.2500        S
# 1                     0  71.2833        C
# 2                     0   7.9250        S
# ...

# %%
print(Y)
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %% [markdown]
# Splitting the total data as test and train data

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=2)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (891, 8) (712, 8) (179, 8)

# %% [markdown]
# Logical regression and model training

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
model=LogisticRegression()

# %% [markdown]
# Use the train data on LogisticRegression

# %%
titanic_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'Age Group',
#        'Siblings and Spouses', 'Parents & children', 'Ticket', 'Fare',
#        'Embarked'],
#       dtype='object')

# %%
ax = sns.countplot(data = titanic_train, x = 'Age Group', )
for bars in ax.containers:
    ax.bar_label(bars)

# %%
ax=sns.countplot(data=titanic_train,x='Age Group',hue='Survived')
for bars in ax.containers:
    ax.bar_label(bars)
